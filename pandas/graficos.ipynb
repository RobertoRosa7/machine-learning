# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('figure', figsize=(15, 8))

# %%
dados = pd.read_csv('../data/aluguel_residencial_sem_outliers.csv', sep=";")
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento             Vista Alegre        3      1       0    70  1200.0
# 3  Apartamento                 Cachambi        2      0       0    50  1300.0
# 4  Apartamento                   Centro        1      0       0    36  1200.0
# 5  Apartamento                   Grajaú        2      1       0    70  1500.0
# 6  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 7  Apartamento               Copacabana        1      0       1    40  2000.0
# 8  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 9  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
area = plt.figure()

# %%
g1 = area.add_subplot(2, 2, 1)
g2 = area.add_subplot(2, 2, 1)
g3 = area.add_subplot(2, 2, 1)
g4 = area.add_subplot(2, 2, 1)
